# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, Flatten, Dropout, BatchNormalization, Input, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.applications import VGG16
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
import matplotlib.pyplot as plt

# Load CIFAR-10 Dataset
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.cifar10.load_data()
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

# Normalize data
X_train = X_train.astype('float32') / 255.0
X_test = X_test.astype('float32') / 255.0

# Data Augmentation
datagen = ImageDataGenerator(
    featurewise_center=False,
    featurewise_std_normalization=False,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.3,
    horizontal_flip=True,
    fill_mode='nearest'
)
datagen.fit(X_train)

# Build the Model
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(32, 32, 3))

# Unfreeze more layers for better fine-tuning
for layer in base_model.layers[:15]:
    layer.trainable = False

# Add custom top layers
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
x = Dense(512, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
outputs = Dense(10, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=outputs)

# Compile the Model with a lower learning rate
model.compile(optimizer=Adam(learning_rate=0.00005),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Callbacks for better training
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-7, verbose=1)
early_stopping = EarlyStopping(monitor='val_accuracy', patience=10, restore_best_weights=True, verbose=1)
model_checkpoint = ModelCheckpoint(filepath='vgg16_cifar10_best.keras', monitor='val_accuracy', save_best_only=True, verbose=1)

# Train the Model
batch_size = 64
epochs = 10

history = model.fit(datagen.flow(X_train, y_train, batch_size=batch_size),
                    steps_per_epoch=len(X_train) // batch_size,
                    validation_data=(X_test, y_test),
                    epochs=epochs,
                    callbacks=[reduce_lr, early_stopping, model_checkpoint])

# Evaluate the Model
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
print(f"Test Accuracy: {test_acc:.4f}")

# Save the Model
model.save('vgg16_cifar10_custom_augmented_final.keras', save_format='tf')

# Plot Training History
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy over Epochs')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss over Epochs')
plt.legend()
plt.show()

import numpy as np
import matplotlib.pyplot as plt
import time

class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# Get some random test images
for x in range(0, 10):
    num_images = 5
    random_indices = np.random.choice(len(X_test), num_images, replace=False)
    test_images = X_test[random_indices]
    test_labels = y_test[random_indices]
    
    # Make predictions
    predictions = model.predict(test_images)
    
    # Plot the images with their predicted labels
    plt.figure(figsize=(15, 5))
    for i in range(num_images):
        plt.subplot(1, num_images, i + 1)
        plt.imshow(test_images[i], interpolation='nearest')  # Use 'nearest' to reduce blur
        plt.axis('off')
        predicted_label = class_names[np.argmax(predictions[i])]
        true_label = class_names[np.argmax(test_labels[i])]
        plt.title(f"Pred: {predicted_label}\nTrue: {true_label}")
    plt.show()
# Out:
# Epoch 1/10
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step - accuracy: 0.2856 - loss: 2.6033
# Epoch 1: val_accuracy improved from -inf to 0.57190, saving model to vgg16_cifar10_best.keras
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 261s 333ms/step - accuracy: 0.2857 - loss: 2.6028 - val_accuracy: 0.5719 - val_loss: 1.2966 - learning_rate: 5.0000e-05
# Epoch 2/10
#   1/781 ━━━━━━━━━━━━━━━━━━━━ 3:48 293ms/step - accuracy: 0.3125 - loss: 2.4104
# 2024-11-28 11:44:32.618215: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# /opt/anaconda3/lib/python3.12/contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(value)
# Epoch 2: val_accuracy improved from 0.57190 to 0.57270, saving model to vgg16_cifar10_best.keras
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.3125 - loss: 2.4104 - val_accuracy: 0.5727 - val_loss: 1.2893 - learning_rate: 5.0000e-05
# Epoch 3/10
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step - accuracy: 0.4554 - loss: 1.7855
# Epoch 3: val_accuracy improved from 0.57270 to 0.62920, saving model to vgg16_cifar10_best.keras
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 255s 326ms/step - accuracy: 0.4554 - loss: 1.7854 - val_accuracy: 0.6292 - val_loss: 1.0950 - learning_rate: 5.0000e-05
# Epoch 4/10
#   1/781 ━━━━━━━━━━━━━━━━━━━━ 3:41 283ms/step - accuracy: 0.4219 - loss: 1.8296
# 2024-11-28 11:49:17.150879: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# Epoch 4: val_accuracy did not improve from 0.62920
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.4219 - loss: 1.8296 - val_accuracy: 0.6291 - val_loss: 1.0935 - learning_rate: 5.0000e-05
# Epoch 5/10
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step - accuracy: 0.5099 - loss: 1.5329
# Epoch 5: val_accuracy improved from 0.62920 to 0.63660, saving model to vgg16_cifar10_best.keras
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 262s 336ms/step - accuracy: 0.5099 - loss: 1.5329 - val_accuracy: 0.6366 - val_loss: 1.0749 - learning_rate: 5.0000e-05
# Epoch 6/10
#   1/781 ━━━━━━━━━━━━━━━━━━━━ 3:39 281ms/step - accuracy: 0.4531 - loss: 1.1625
# Epoch 6: val_accuracy improved from 0.63660 to 0.63700, saving model to vgg16_cifar10_best.keras
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.4531 - loss: 1.1625 - val_accuracy: 0.6370 - val_loss: 1.0749 - learning_rate: 5.0000e-05
# Epoch 7/10
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 0.5404 - loss: 1.4146
# Epoch 7: val_accuracy improved from 0.63700 to 0.65900, saving model to vgg16_cifar10_best.keras
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 263s 337ms/step - accuracy: 0.5404 - loss: 1.4145 - val_accuracy: 0.6590 - val_loss: 1.0118 - learning_rate: 5.0000e-05
# Epoch 8/10
#   1/781 ━━━━━━━━━━━━━━━━━━━━ 3:35 277ms/step - accuracy: 0.5156 - loss: 1.4467
# 2024-11-28 11:59:01.954515: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# Epoch 8: val_accuracy improved from 0.65900 to 0.66170, saving model to vgg16_cifar10_best.keras
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.5156 - loss: 1.4467 - val_accuracy: 0.6617 - val_loss: 1.0025 - learning_rate: 5.0000e-05
# Epoch 9/10
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 0.5659 - loss: 1.3118
# Epoch 9: val_accuracy improved from 0.66170 to 0.68630, saving model to vgg16_cifar10_best.keras
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 276s 353ms/step - accuracy: 0.5660 - loss: 1.3118 - val_accuracy: 0.6863 - val_loss: 0.9420 - learning_rate: 5.0000e-05
# Epoch 10/10
#   1/781 ━━━━━━━━━━━━━━━━━━━━ 3:44 288ms/step - accuracy: 0.5625 - loss: 1.1958
# Epoch 10: val_accuracy improved from 0.68630 to 0.68880, saving model to vgg16_cifar10_best.keras
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 30s 37ms/step - accuracy: 0.5625 - loss: 1.1958 - val_accuracy: 0.6888 - val_loss: 0.9350 - learning_rate: 5.0000e-05
# Restoring model weights from the end of the best epoch: 10.
# 313/313 - 28s - 91ms/step - accuracy: 0.6888 - loss: 0.9350
# WARNING:absl:The `save_format` argument is deprecated in Keras 3. We recommend removing this argument as it can be inferred from the file path. Received: save_format=tf
# Test Accuracy: 0.6888

# %%
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
